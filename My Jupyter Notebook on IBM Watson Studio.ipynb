# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio.

# %% [markdown]
# **Juliano Zen.**
#
# Financial analyst.

# %% [markdown]
# *As a data (financial) analyst, Data Science seemed to me like the next logical step on my carreer.*
#  I wish to develop further analytical knowledge and develop inteligent solutions, using data in evermore efficient ways.*

# %% [markdown]
# ### The following code is a classic that never dies:

# %%
#Strings setup (overdone, I know, lol)

string1=("Hello world! ")
string2=("Here we go again.")

#Command (yeah)

print(string1 + string2)
# Out:
# Hello world! Here we go again.

# %% [markdown]
# ### Syntax Highlighting and code block:

# %% [markdown]
# Example of a `highlighted` chunk
#
#
# Example code chunk (Rmarkdown deja-vu feelings):
# ```python
# string = "Syntax Highlighting"
# print(string)
# ```

# %% [markdown]
# ### Table:

# %% [markdown]
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3

# %% [markdown]
# ### Blockquotes:

# %% [markdown]
# > If one does not know to which port one is sailing, no wind is favorable.
#
# Lucius Annaeus Seneca
